# %%
2 + 2
# Out:
# 4

# %%
import math

# %%
import yfinance as yf #collect data from yfinance
import pandas as pd #data anaysis
import matplotlib.pyplot as plt #data visualisation
import seaborn as sns

# %%
start_date = '2025-01-01'
end_date = '2025-10-01'

# %%
bitcoin = yf.download('BTC-USD',start_date,end_date )
# Out:
# /tmp/ipython-input-3860064882.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   bitcoin = yf.download('BTC-USD',start_date,end_date )
# [*********************100%***********************]  1 of 1 completed

# %%
bitcoin
# Out:
# Price               Close           High            Low           Open  \
# Ticker            BTC-USD        BTC-USD        BTC-USD        BTC-USD
# Date
# 2025-01-01   94419.757812   94929.867188   92788.125000   93425.101562
# 2025-01-02   96886.875000   97739.820312   94201.570312   94416.289062
# 2025-01-03   98107.429688   98956.914062   96034.617188   96881.726562
# 2025-01-04   98236.226562   98734.429688   97562.976562   98106.992188
# 2025-01-05   98314.960938   98813.304688   97291.765625   98233.906250
# ...                   ...            ...            ...            ...
# 2025-09-26  109712.828125  110359.195312  108728.976562  109041.296875
# 2025-09-27  109681.945312  109778.500000  109144.296875  109707.140625
# 2025-09-28  112122.640625  112375.484375  109236.945312  109681.945312
# 2025-09-29  114400.382812  114473.570312  111589.953125  112117.875000
# 2025-09-30  114056.085938  114836.617188  112740.562500  114396.523438
#
# Price            Volume
# ...

# %%
TSLA=yf.download('TSLA',start_date,end_date)
# Out:
# /tmp/ipython-input-1465262508.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   TSLA=yf.download('TSLA',start_date,end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
TSLA
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2025-01-02  379.279999  392.730011  373.040009  390.100006  109710700
# 2025-01-03  410.440002  411.880005  379.450012  381.480011   95423300
# 2025-01-06  411.049988  426.429993  401.700012  423.200012   85516500
# 2025-01-07  394.359985  414.329987  390.000000  405.829987   75699500
# 2025-01-08  394.940002  402.500000  387.399994  392.950012   73038800
# ...                ...         ...         ...         ...        ...
# 2025-09-24  442.790009  444.209991  429.029999  429.829987   93133600
# 2025-09-25  423.390015  435.350006  419.079987  435.239990   96746400
# 2025-09-26  440.399994  440.470001  421.019989  428.299988  101628200
# 2025-09-29  443.209991  450.980011  439.500000  444.350006   79491500
# 2025-09-30  444.720001  445.000000  433.119995  441.519989   74358000
#
# [186 rows x 5 columns]

# %%
AAPL=yf.download('AAPL',start_date,end_date)
# Out:
# /tmp/ipython-input-1526627162.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   AAPL=yf.download('AAPL',start_date,end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
AAPL
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2025-01-02  242.987427  248.218856  240.964609  248.049444  55740700
# 2025-01-03  242.499161  243.316252  241.034359  242.499161  40244100
# 2025-01-06  244.133347  246.455106  242.339711  243.445785  45045600
# 2025-01-07  241.353226  244.681407  240.496267  242.120491  40856000
# 2025-01-08  241.841461  242.847898  239.200841  241.064222  37628900
# ...                ...         ...         ...         ...       ...
# 2025-09-24  252.309998  255.740005  251.039993  255.220001  42303700
# 2025-09-25  256.869995  257.170013  251.710007  253.210007  55202100
# 2025-09-26  255.460007  257.600006  253.779999  254.100006  46076300
# 2025-09-29  254.429993  255.000000  253.009995  254.559998  40127700
# 2025-09-30  254.630005  255.919998  253.110001  254.860001  37704300
#
# [186 rows x 5 columns]

# %%
AMD=yf.download('AMD',start_date,end_date)
# Out:
# /tmp/ipython-input-3391567246.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   AMD=yf.download('AMD',start_date,end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
AMD
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             AMD         AMD         AMD         AMD       AMD
# Date
# 2025-01-02  120.629997  123.139999  119.440002  122.290001  34256200
# 2025-01-03  125.370003  125.559998  121.419998  121.650002  36785300
# 2025-01-06  129.550003  130.729996  127.360001  129.070007  48020200
# 2025-01-07  127.330002  131.710007  126.849998  130.509995  39220400
# 2025-01-08  121.839996  125.300003  120.120003  124.510002  46723100
# ...                ...         ...         ...         ...       ...
# 2025-09-24  160.880005  165.100006  158.429993  162.979996  38464100
# 2025-09-25  161.270004  161.630005  154.779999  157.139999  36809900
# 2025-09-26  159.460007  162.110001  157.050003  160.520004  30316900
# 2025-09-29  161.360001  164.300003  159.899994  160.119995  39828800
# 2025-09-30  161.789993  162.279999  159.330002  160.789993  29669300
#
# [186 rows x 5 columns]

# %%
AMD['Close'].plot()
plt.xlabel('date')
plt.ylabel('price')
plt.title('AMD stock price')
# Out:
# Text(0.5, 1.0, 'AMD stock price')

# %%
tickers=['AMD','AAPL','TSLA']
portfolio=yf.download(tickers,start_date,end_date)
# Out:
# /tmp/ipython-input-3157764911.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   portfolio=yf.download(tickers,start_date,end_date)
# [*********************100%***********************]  3 of 3 completed

# %%
close=portfolio['Close']
close.head() #top 5 rows
# Out:
# Ticker            AAPL         AMD        TSLA
# Date
# 2025-01-02  242.987427  120.629997  379.279999
# 2025-01-03  242.499161  125.370003  410.440002
# 2025-01-06  244.133347  129.550003  411.049988
# 2025-01-07  241.353226  127.330002  394.359985
# 2025-01-08  241.841461  121.839996  394.940002

# %%
portfolio['Close'].pct_change().corr()
# Out:
# Ticker      AAPL       AMD      TSLA
# Ticker
# AAPL    1.000000  0.559644  0.565212
# AMD     0.559644  1.000000  0.579228
# TSLA    0.565212  0.579228  1.000000

# %%
corrMatrix=portfolio['Close'].pct_change().corr()
sns.heatmap(corrMatrix,annot=True)
# Out:
# <Axes: xlabel='Ticker', ylabel='Ticker'>
